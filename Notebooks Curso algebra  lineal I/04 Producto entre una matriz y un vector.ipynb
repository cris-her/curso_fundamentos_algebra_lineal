# %%
import numpy as np

# %%
escalar = 5.678
vector = np.array([2,3])
matriz = np.array([[1,2], [3,4],[5,6]])

# %%
A = matriz * vector

# %%
# producto punto
B = matriz.dot(vector)
print(B)
# Out:
# [ 8 18 28]

# %%
print(matriz)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
print(vector)
# Out:
# [2 3]

# %%
# Utilizando broadcasting obtuvimos el resultado
print(A)
# Out:
# [[ 2  6]
#  [ 6 12]
#  [10 18]]

# %% [markdown]
# ## Producto interno o producto punto (.dot)

# %% [markdown]
# Realizamos la siguiente operacion
#
# ![](https://matematicasmodernas.com/wp-content/uploads/2014/04/pp.jpeg)

# %%
print(matriz)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
print(vector)
# Out:
# [2 3]

# %%
# Operacion manual
print(np.array([(1*2 + 2*3), (3*2 + 3*4), (5*2 + 6*3)]))
# Out:
# [ 8 18 28]

# %%
# Operacion python
print(B)
# Out:
# [ 8 18 28]

# %% [markdown]
# ### Forma dos de producto interno (punto)

# %%
B = matriz.dot(vector)
C = np.dot(matriz, vector)

# %%
print(B)
# Out:
# [ 8 18 28]

# %%
print(C)
# Out:
# [ 8 18 28]

# %% [markdown]
# ### Ejercicio vector por matriz

# %%
D = np.dot(vector, matriz)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-bd61c2028387> in <module>()
# ----> 1 D = np.dot(vector, matriz)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (2,) and (3,2) not aligned: 2 (dim 0) != 3 (dim 0)

# %%
F = vector.dot(matriz)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-f7e7e059f4f9> in <module>()
# ----> 1 F = vector.dot(matriz)
#
# ValueError: shapes (2,) and (3,2) not aligned: 2 (dim 0) != 3 (dim 0)

# %%
y = 7*x+2 y = 3*x+5

# %%
A = np.array([[7,-1], [3, -1]])
print(A)
# Out:
# [[ 7 -1]
#  [ 3 -1]]

# %%
b = np.array([[-2], [-5]])
print(b)
# Out:
# [[-2]
#  [-5]]

# %%
inversa_A = np.linalg.inv(A)
print(inversa_A)
# Out:
# [[ 0.25 -0.25]
#  [ 0.75 -1.75]]

# %%
x = inversa_A.dot(b)
print(x)
# Out:
# [[0.75]
#  [7.25]]
