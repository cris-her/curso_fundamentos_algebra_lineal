# %%
import numpy as np

# %%
vector = np.array([1,2,0,5,6,0])

# %%
# Calculo L0 cantidad elementos distinto a cero
print(np.linalg.norm(vector, ord=0))
# Out:
# 4.0

# %%
# Calculo L1 suma valores absolutos del vector
vector = np.array([1,-1,1,-1,1])

print(np.linalg.norm(vector, ord=1))
# Out:
# 5.0

# %%
# Calculo de L2 distancia eculidiana
vector = np.array([1,1])

print(np.linalg.norm(vector))
print(np.linalg.norm(vector, ord=2))
# Out:
# 1.4142135623730951
# 1.4142135623730951

# %%
# Calculo usando L2^2
vector = np.array([1,2,3,4,5,6])
print(vector)
# Out:
# [1 2 3 4 5 6]

# %%
print(np.linalg.norm(vector, ord=2)**2)
# Out:
# 91.0

# %%
print(vector.T.dot(vector))
# Out:
# 91

# %%
# Norma infinito
vector = np.array([1,2,3,-100])
print(np.linalg.norm(vector, ord=np.inf))
# Out:
# 100.0
