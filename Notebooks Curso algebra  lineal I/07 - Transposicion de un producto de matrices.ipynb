# %%
import numpy as np

# %%
A = np.array([[2,3], [5,7], [11,13]])
B = np.array([[1,3], [2,1]])

# %%
print(A)
# Out:
# [[ 2  3]
#  [ 5  7]
#  [11 13]]

# %%
print(B)
# Out:
# [[1 3]
#  [2 1]]

# %%
AB_t = A.dot(B).T
print(AB_t)
# Out:
# [[ 8 19 37]
#  [ 9 22 46]]

# %%
B_tA_t = B.T.dot(A.T)

# %%
print(B_tA_t == AB_t)
# Out:
# [[ True  True  True]
#  [ True  True  True]]
