# %%
import numpy as np

# %%
escalar = 5.678
vector = np.array([3,4,5])
matriz = np.array([[1,2], [3,4],[5,6]])

# %%
A = matriz + vector
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-39b5823f3641> in <module>()
# ----> 1 A = matriz + vector
#
# ValueError: operands could not be broadcast together with shapes (3,2) (3,)

# %%
# Utilizo la transpuesta de la matriz
A = matriz.T + vector

# %%
print(matriz.T)
# Out:
# [[1 3 5]
#  [2 4 6]]

# %%
print(vector)
# Out:
# [3 4 5]

# %%
# Python hace broadcasting internamente repitiendo el vector como segunda fila para ajustarse a la matriz

# %%
print(A)
# Out:
# [[ 4  7 10]
#  [ 5  8 11]]
