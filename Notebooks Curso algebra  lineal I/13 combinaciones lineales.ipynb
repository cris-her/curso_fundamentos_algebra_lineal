# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
# Cargamos el acceso a  nuestro drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks/Curso algebra  lineal I

# %%
# Nos movemos a la ruta del notebook a cargar y verificamos
# %cd '/content/drive/My Drive/Colab Notebooks/Curso algebra  lineal I'
# Out:
# /content/drive/My Drive/Colab Notebooks/Curso algebra  lineal I

# %%
# Corremos el notebook
# %run './funciones_auxiliares/graficarVectores.ipynb'

# %%
v1= np.array([2,5])
v2 = np.array([3,2])

# %%
v1v2 = 2*v1 + 1*v2

# %%
print(v1v2)
# Out:
# [ 7 12]

# %%
graficarVectores([v1, v2, v1v2], ["orange", "blue", "red"])

plt.xlim(-1, 8)
plt.ylim(-1, 12)
# Out:
# (-1.0, 12.0)

# %%
for a in range(-10,10):
  for b in range(-10,10):
    plt.scatter(v1[0]*a + v2[0]*b, v1[1]*a + v2[1]*b,
                marker = '.',
                color= "orange")

plt.xlim(-100, 100) 
plt.ylim(-100, 100)

plt.axvline(x=0, color='grey')
plt.axhline(y=0, color='grey')


plt.show()
